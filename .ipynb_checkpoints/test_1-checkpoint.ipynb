# %%
import numpy as np

# %%
q = 3095.3589668330847
b = 1.287623862082167

# %%
q/b
# Out:
# 2403.9310376150524

# %%
r = [5.0860913045319505, 5.015022370326535, 6.1461399746947, 2.4776531655384577, 2.796297102946033, 4.146156068047297, 3.0212568164481572, 2.999618930873585, 5.190177559930035]
a = 0
for i in range(9):
    a += r[i]

# %%
a
# Out:
# 36.87841329333675

# %%
q1 = {0: [3095.3589668330847, 1675.0806322673584], 1: [1507.8820814361306, 3094.7059079167648], 2: [1515.7037356081455, 1403.2933897542016], 3: [2647.0002864978587, 1343.3341478792524], 4: [1215.3045884096164, 1724.646420939803], 5: [1701.8065137408914, 1232.5593118817087], 6: [1348.1237686014742, 1701.9746790144918], 7: [2523.3210720546913, 1808.2518957055765], 8: [3740.4970424205244, 1642.9383849732117], 9: [1601.7746087276773, 1150.9159290962084], 10: [1992.9324662092345, 2940.132246767442], 11: [4465.5436869002315, 1525.8040456812184], 12: [3158.705121017037, 2672.8083805514943], 13: [2384.277802277547, 2241.540482712043], 14: [1825.5467310405015, 1424.6908170688919], 15: [1335.6823073371859, 2644.597755501601], 16: [1838.7153941899185, 2464.142728820218], 17: [3052.1069193206877, 1779.193621846712], 18: [3458.442655291812, 1767.5780488885887], 19: [2165.8997471708353, 1335.285385232881]}
task0_q = {}
task0_q_l = [0]*20
for i in range(20):
    task0_q[i] = q1[i][0]
    task0_q_l[i] = q1[i][0]

# q1[0][0]

# %%
task0_q
# Out:
# {0: 3095.3589668330847,
#  1: 1507.8820814361306,
#  2: 1515.7037356081455,
#  3: 2647.0002864978587,
#  4: 1215.3045884096164,
#  5: 1701.8065137408914,
#  6: 1348.1237686014742,
#  7: 2523.3210720546913,
#  8: 3740.4970424205244,
#  9: 1601.7746087276773,
#  10: 1992.9324662092345,
#  11: 4465.5436869002315,
#  12: 3158.705121017037,
#  13: 2384.277802277547,
#  14: 1825.5467310405015,
#  15: 1335.6823073371859,
#  16: 1838.7153941899185,
#  17: 3052.1069193206877,
#  18: 3458.442655291812,
#  19: 2165.8997471708353}

# %%
sorted(task0_q_l)
# Out:
# [1215.3045884096164,
#  1335.6823073371859,
#  1348.1237686014742,
#  1507.8820814361306,
#  1515.7037356081455,
#  1601.7746087276773,
#  1701.8065137408914,
#  1825.5467310405015,
#  1838.7153941899185,
#  1992.9324662092345,
#  2165.8997471708353,
#  2384.277802277547,
#  2523.3210720546913,
#  2647.0002864978587,
#  3052.1069193206877,
#  3095.3589668330847,
#  3158.705121017037,
#  3458.442655291812,
#  3740.4970424205244,
#  4465.5436869002315]

# %%
task0_q
# Out:
# {0: 3095.3589668330847,
#  1: 1507.8820814361306,
#  2: 1515.7037356081455,
#  3: 2647.0002864978587,
#  4: 1215.3045884096164,
#  5: 1701.8065137408914,
#  6: 1348.1237686014742,
#  7: 2523.3210720546913,
#  8: 3740.4970424205244,
#  9: 1601.7746087276773,
#  10: 1992.9324662092345,
#  11: 4465.5436869002315,
#  12: 3158.705121017037,
#  13: 2384.277802277547,
#  14: 1825.5467310405015,
#  15: 1335.6823073371859,
#  16: 1838.7153941899185,
#  17: 3052.1069193206877,
#  18: 3458.442655291812,
#  19: 2165.8997471708353}

# %%
budget_dic = {}
for i in range(20):
    a = np.random.uniform(1, 10, 2)
    budget_dic[i] += list(a)
    #print(budget_dic)#输出客户端的报价
for i in range(client_count):
    a = max(budget_dic[i])
    b = min(budget_dic[i])
    print("客户端报价的范围为：{}~{}".format(a,b))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-64-18c27471e62d> in <module>
#       2 for i in range(20):
#       3     a = np.random.uniform(1, 10, 2)
# ----> 4     budget_dic[i] += list(a)
#       5     #print(budget_dic)#输出客户端的报价
#       6 for i in range(client_count):
#
# KeyError: 0

# %%
sum = 0
for i in range(101):
    sum += i
